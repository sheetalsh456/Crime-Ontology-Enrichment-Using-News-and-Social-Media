# %%
import newspaper

# %%
file = open('urls', 'r')
data = file.readlines()

urls = []

for url in data:
    url = url.rstrip('\n')
    urls.append(url)
    
urls
# Out:
# ['https://timesofindia.indiatimes.com/city/mumbai/6-year-old-abducted-girl-found-dead-in-railway-toilet-in-navsari/articleshow/63462708.cms',
#  'https://economictimes.indiatimes.com/news/politics-and-nation/sushma-swaraj-to-visit-japan-for-strategic-dialogue/articleshow/63488634.cms',
#  'https://thelogicalindian.com/environment/illegal-stone-quarries-in-bannerghatta/',
#  'https://timesofindia.indiatimes.com/city/pune/beed-girl-throws-light-on-rampant-mass-copying-before-child-rights-commission/articleshow/63472161.cms',
#  'http://odishasuntimes.com/mahaprayan-ambulance-failure-in-odisha-body-carried-on-rickshaw-baby-delivered-in-auto/',
#  'https://economictimes.indiatimes.com/news/politics-and-nation/congress-will-disappear-from-karnataka-like-other-states-prakash-javadekar/articleshow/63487965.cms',
#  'https://timesofindia.indiatimes.com/india/congress-will-disappear-from-karnataka-like-other-states-prakash-javadekar/articleshow/63487837.cms',
#  'https://www.japantimes.co.jp/news/2018/03/27/asia-pacific/north-korean-leaders-train-unlike/#.WrpSnXVuY8o',
#  'https://www.nytimes.com/aponline/2018/03/27/world/asia/ap-as-nkorea-the-mystery-train.html',
#  'https://timesofindia.indiatimes.com/india/amit-shah-accuses-siddaramaiah-govt-of-dividing-hindus/articleshow/63482038.cms',
#  'https://www.thehindubusinessline.com/news/national/amit-shah-accuses-siddaramaiah-govt-of-dividing-hindus/article23364780.ece',
#  'https://timesofindia.indiatimes.com/city/bengaluru/karnataka-polls-not-averse-to-seers-and-pontiffs-contesting-on-our-party-ticket-says-amit-shah/articleshow/63480352.cms',
#  'http://theworldvibe.com/63480378-cms/',
#  'http://brighterkashmir.com/man-loses-wife-and-2-kids-in-gambling-gets-divorce/',
#  'https://timesofindia.indiatimes.com/city/kanpur/Man-loses-wife-as-stake-in-IPL-gambling/articleshow/52480224.cms',
#  'https://timesofindia.indiatimes.com/india/heated-exchanges-between-aiadmk-congress-mps-after-lok-sabha-adjourns/articleshow/63480945.cms',
#  'https://www.indiatoday.in/pti-feed/story/heated-exchanges-between-aiadmk-cong-mps-after-ls-adjourns-1198771-2018-03-27',
#  'https://timesofindia.indiatimes.com/india/jk-undo-negative-perception-about-kashmir-says-tourism-minister-tassaduq-mufti/articleshow/63485013.cms',
#  'https://dailyworld.in/undo-negative-perception-about-kashmir-says-tourism-minister/',
#  'https://timesofindia.indiatimes.com/india/up-assembly-passes-stringent-crime-control-bill-amid-opposition-walkout/articleshow/63483701.cms',
#  'https://www.theweek.in/news/india/2018/03/27/uttar-pradesh-assembly-passes-stringent-crime-control-bill-amid-opposition-walkout.html',
#  'https://timesofindia.indiatimes.com/india/cbdt-extends-pan-aadhaar-linking-deadline-to-june-30/articleshow/63491050.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop',
#  'https://timesofindia.indiatimes.com/india/sushma-swaraj-to-visit-japan-for-strategic-dialogue/articleshow/63486098.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop',
#  'https://timesofindia.indiatimes.com/india/congress-will-disappear-from-karnataka-like-other-states-prakash-javadekar/articleshow/63487837.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop',
#  'https://blogs.timesofindia.indiatimes.com/sanjeev-singh-blog/did-samajwadi-party-really-want-bsp-to-win-up-rajya-sabha-polls/',
#  'https://timesofindia.indiatimes.com/india/delhi-court-orders-attachment-of-vijay-mallyas-properties-in-pmla-case/articleshow/63486193.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop',
#  'http://indianexpress.com/article/india/crime/assam-crowds-throng-centres-to-check-draft-nrc-many-nellie-muslims-not-on-list-5008067 ',
#  'http://indianexpress.com/article/india/crime/railway-push-to-heritage-conservation-steam-engines-to-return-to-mountains-4966587 ',
#  'http://indianexpress.com/article/india/crime/pak-border-squeeze-chokes-indian-traders',
#  'http://indianexpress.com/article/india/crime/another-accused-in-pehlu-khan-lynching-case-gets-bail-4789888 ']

# %%
from nltk import *
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn

# %%
def penn_to_wn(tag):
    """ Convert between a Penn Treebank tag to a simplified Wordnet tag """
    if tag.startswith('N'):
        return 'n'
 
    if tag.startswith('V'):
        return 'v'
 
    if tag.startswith('J'):
        return 'a'
 
    if tag.startswith('R'):
        return 'r'
 
    return None
 
def tagged_to_synset(word, tag):
    wn_tag = penn_to_wn(tag)
    if wn_tag is None:
        return None
    try:
        return wn.synsets(word, wn_tag)[0]
    except:
        return None

# %%
def sentence_similarity(sentence1, sentence2):
    """ compute the sentence similarity using Wordnet """
#     print(sentence1, sentence2)
    # Tokenize and tag
    sentence1 = pos_tag(word_tokenize(sentence1))
    sentence2 = pos_tag(word_tokenize(sentence2))
 
    # Get the synsets for the tagged words
    synsets1 = [tagged_to_synset(*tagged_word) for tagged_word in sentence1]
    synsets2 = [tagged_to_synset(*tagged_word) for tagged_word in sentence2]
 
    # Filter out the Nones
    synsets1 = [ss for ss in synsets1 if ss]
    synsets2 = [ss for ss in synsets2 if ss]

#     print(synsets1, synsets2)
    score, count = 0.0, 0
 
    # For each word in the first sentence
    for synset in synsets1:
        # Get the similarity value of the most similar word in the other sentence
        scores = [synset.path_similarity(ss) for ss in synsets2]
        scores.append(0)
        best_score = max([score for score in scores if score is not None])
 
        # Check that the similarity could have been computed
        if best_score is not None:
            score += best_score
            count += 1
 
    # Average the values
    if count != 0:
        score /= count
    return score

def symmetric_sentence_similarity(sentence1, sentence2):
    """ compute the symmetric sentence similarity using Wordnet """
    return (sentence_similarity(sentence1, sentence2) + sentence_similarity(sentence2, sentence1)) / 2

# %%
def get_continuous_chunks(text):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []
    for i in chunked:
            if type(i) == Tree:
                current_chunk.append(i.label()[:3] + "-")
                current_chunk.append(" ".join([token for token, pos in i.leaves()]))
            elif current_chunk:
                named_entity = " ".join(current_chunk)
                if named_entity not in continuous_chunk:
                    continuous_chunk.append(named_entity)
                    current_chunk = []
            else:
                continue
    return continuous_chunk

# %%
def get_relation_tuples(sentences, image, image_caption):
    relation_tuples = []
    for sentence in sentences:
        similarity_score = symmetric_sentence_similarity(sentence, image_caption)
        rel_tuple_single = []
        rel_tuple_single = get_continuous_chunks(sentence)
        
        if len(rel_tuple_single):
            tokens = word_tokenize(sentence)
            tagged = pos_tag(tokens)

        entities = chunk.ne_chunk(tagged)
        for entity in entities:
            if len(entity)>1 and (entity[1] == 'VB' or entity[1] == 'VBD' or entity[1] == 'VBN' or entity[1] == 'VM'):
                if entity[0] not in stopwords.words('english'):
                    rel_tuple_single.append('REL-'+entity[0])
        rel_tuple_single.append('IMG-'+image)
        rel_tuple_single.append('RM-'+str(similarity_score))

        if len(rel_tuple_single):
            relation_tuples.append(rel_tuple_single)

    with open("input.txt", "a") as myfile:
        myfile.write(str(relation_tuples)+'\n')

# %%
from requests import get
from bs4 import BeautifulSoup

def get_image_caption(url):
    response = get(url)
    caption = ""
    html_soup = BeautifulSoup(response.text, 'html.parser')
    print(url)
    if url.find('indianexpress') is not -1:
        image_containers = html_soup.find_all('span', class_ = 'custom-caption')
        if len(image_containers):
            caption = image_containers[0].text
    elif url.find('deccanchronicle') is not -1:
        image_containers = html_soup.find_all('div', class_ = 'storyimg-caption')
        if len(image_containers):
            caption = image_containers[0].text
    return caption

# %%
articles = []

for i, url in enumerate(urls):
    print ('Article number %d' % (i+1))
    article = newspaper.Article(url=url, language='en')
    article.download()
    article.parse()
    article.nlp()
    try:
        get_relation_tuples(sent_tokenize(article.summary), article.top_image, get_image_caption(url))
        print('Added to inputs.txt')
    except:
        print ('Invalid Article')
    print ('----------------')
# Out:
# Article number 1
# https://timesofindia.indiatimes.com/city/mumbai/6-year-old-abducted-girl-found-dead-in-railway-toilet-in-navsari/articleshow/63462708.cms
# MUMBAI: A 6-year-old girl who was abducted by an unidentified woman from outside her building on Saturday was found dead in a ladies toilet at Navsari railway station in Gujarat The Tuling police in Nalasopara (east) had prepared a sketch of the kidnapper who was vaguely captured on a closed circuit television (CCTV) outside the Sai Arpan building in Vijay Nagar where the girl Anjali Saroj stayed with her parents.The CCTV footage showed Anjali being forcibly taken away by the woman at around 8 pm.
# [Synset('mumbai.n.01'), Synset('girl.n.01'), Synset('be.v.01'), Synset('kidnap.v.01'), Synset('unidentified.s.01'), Synset('woman.n.01'), Synset('building.n.01'), Synset('saturday.n.01'), Synset('be.v.01'), Synset('establish.v.01'), Synset('dead.a.01'), Synset('lady.n.01'), Synset('toilet.n.01'), Synset('railway.n.01'), Synset('station.n.01'), Synset('gujarat.n.01'), Synset('police.n.01'), Synset('east.n.01'), Synset('have.v.01'), Synset('fix.v.12'), Synset('sketch.n.01'), Synset('kidnapper.n.01'), Synset('be.v.01'), Synset('vaguely.r.01'), Synset('capture.v.01'), Synset('closed.a.01'), Synset('circuit.n.01'), Synset('television.n.01'), Synset('building.n.01'), Synset('girl.n.01'), Synset('stay.v.01'), Synset('footage.n.01'), Synset('show.v.01'), Synset('be.v.01'), Synset('forcibly.r.01'), Synset('take.v.01'), Synset('away.r.01'), Synset('woman.n.01'), Synset('autopsy.n.01')] []
#  MUMBAI: A 6-year-old girl who was abducted by an unidentified woman from outside her building on Saturday was found dead in a ladies toilet at Navsari railway station in Gujarat The Tuling police in Nalasopara (east) had prepared a sketch of the kidnapper who was vaguely captured on a closed circuit television (CCTV) outside the Sai Arpan building in Vijay Nagar where the girl Anjali Saroj stayed with her parents.The CCTV footage showed Anjali being forcibly taken away by the woman at around 8 pm.
# [] [Synset('mumbai.n.01'), Synset('girl.n.01'), Synset('be.v.01'), Synset('kidnap.v.01'), Synset('unidentified.s.01'), Synset('woman.n.01'), Synset('building.n.01'), Synset('saturday.n.01'), Synset('be.v.01'), Synset('establish.v.01'), Synset('dead.a.01'), Synset('lady.n.01'), Synset('toilet.n.01'), Synset('railway.n.01'), Synset('station.n.01'), Synset('gujarat.n.01'), Synset('police.n.01'), Synset('east.n.01'), Synset('have.v.01'), Synset('fix.v.12'), Synset('sketch.n.01'), Synset('kidnapper.n.01'), Synset('be.v.01'), Synset('vaguely.r.01'), Synset('capture.v.01'), Synset('closed.a.01'), Synset('circuit.n.01'), Synset('television.n.01'), Synset('building.n.01'), Synset('girl.n.01'), Synset('stay.v.01'), Synset('footage.n.01'), Synset('show.v.01'), Synset('be.v.01'), Synset('forcibly.r.01'), Synset('take.v.01'), Synset('away.r.01'), Synset('woman.n.01'), Synset('autopsy.n.01')]
# A kidnapping case was registered with the police.Just when the cops circulated the woman’s sketch across police stations and in the locality, police were informed about the body of a child found in a ladies toilet in Navsari on Sunday night.The body was identified as that of Anjali.
# [Synset('kidnapping.n.01'), Synset('case.n.01'), Synset('be.v.01'), Synset('register.v.01'), Synset('bull.n.05'), Synset('go_around.v.02'), Synset('woman.n.01'), Synset('second.n.01'), Synset('sketch.n.01'), Synset('police.n.01'), Synset('stations.n.01'), Synset('vicinity.n.01'), Synset('police.n.01'), Synset('be.v.01'), Synset('inform.v.01'), Synset('body.n.01'), Synset('child.n.01'), Synset('establish.v.01'), Synset('lady.n.01'), Synset('toilet.n.01'), Synset('sunday.n.01'), Synset('body.n.01'), Synset('be.v.01'), Synset('identify.v.01')] []
#  A kidnapping case was registered with the police.Just when the cops circulated the woman’s sketch across police stations and in the locality, police were informed about the body of a child found in a ladies toilet in Navsari on Sunday night.The body was identified as that of Anjali.
# [] [Synset('kidnapping.n.01'), Synset('case.n.01'), Synset('be.v.01'), Synset('register.v.01'), Synset('bull.n.05'), Synset('go_around.v.02'), Synset('woman.n.01'), Synset('second.n.01'), Synset('sketch.n.01'), Synset('police.n.01'), Synset('stations.n.01'), Synset('vicinity.n.01'), Synset('police.n.01'), Synset('be.v.01'), Synset('inform.v.01'), Synset('body.n.01'), Synset('child.n.01'), Synset('establish.v.01'), Synset('lady.n.01'), Synset('toilet.n.01'), Synset('sunday.n.01'), Synset('body.n.01'), Synset('be.v.01'), Synset('identify.v.01')]
# The body has been sent for autopsy to ascertain cause of death.
# [Synset('body.n.01'), Synset('have.v.01'), Synset('be.v.01'), Synset('send.v.01'), Synset('autopsy.n.01'), Synset('determine.v.01'), Synset('cause.n.01'), Synset('death.n.01')] []
#  The body has been sent for autopsy to ascertain cause of death.
# [] [Synset('body.n.01'), Synset('have.v.01'), Synset('be.v.01'), Synset('send.v.01'), Synset('autopsy.n.01'), Synset('determine.v.01'), Synset('cause.n.01'), Synset('death.n.01')]
# Added to inputs.txt
# ----------------
# Article number 2
# https://economictimes.indiatimes.com/news/politics-and-nation/sushma-swaraj-to-visit-japan-for-strategic-dialogue/articleshow/63488634.cms
# NEW DELHI: External Affairs Minister Sushma Swaraj will pay a three-day visit to Japan starting tomorrow during which she will co-chair the strategic dialogue with her Japanese counterpart Taro Kono and review the entire gamut of bilateral ties.The 9th India-Japan Strategic Dialogue will take place on March 29.
# [Synset('new.a.01'), Synset('delhi.n.01'), Synset('external.n.01'), Synset('personal_business.n.01'), Synset('curate.n.01'), Synset('pay.v.01'), Synset('visit.n.01'), Synset('japan.n.01'), Synset('get_down.v.07'), Synset('tomorrow.n.01'), Synset('strategic.a.01'), Synset('dialogue.n.01'), Synset('japanese.a.01'), Synset('counterpart.n.01'), Synset('taro.n.01'), Synset('review.v.01'), Synset('entire.s.01'), Synset('gamut.n.01'), Synset('bilateral.s.01'), Synset('dialogue.n.01'), Synset('take.v.01'), Synset('topographic_point.n.01'), Synset('march.n.01')] []
#  NEW DELHI: External Affairs Minister Sushma Swaraj will pay a three-day visit to Japan starting tomorrow during which she will co-chair the strategic dialogue with her Japanese counterpart Taro Kono and review the entire gamut of bilateral ties.The 9th India-Japan Strategic Dialogue will take place on March 29.
# [] [Synset('new.a.01'), Synset('delhi.n.01'), Synset('external.n.01'), Synset('personal_business.n.01'), Synset('curate.n.01'), Synset('pay.v.01'), Synset('visit.n.01'), Synset('japan.n.01'), Synset('get_down.v.07'), Synset('tomorrow.n.01'), Synset('strategic.a.01'), Synset('dialogue.n.01'), Synset('japanese.a.01'), Synset('counterpart.n.01'), Synset('taro.n.01'), Synset('review.v.01'), Synset('entire.s.01'), Synset('gamut.n.01'), Synset('bilateral.s.01'), Synset('dialogue.n.01'), Synset('take.v.01'), Synset('topographic_point.n.01'), Synset('march.n.01')]
# "The two sides will review all aspects of bilateral relations and exchange views on regional and international issues of common interest," a Ministry of External Affairs (MEA) statement said.India and Japan concluded a Special Strategic and Global Partnership during the visit of Prime Minister Narendra Modi to Japan in 2014.
# [Synset('side.n.01'), Synset('review.v.01'), Synset('aspect.n.01'), Synset('bilateral.s.01'), Synset('relations.n.01'), Synset('exchange.n.01'), Synset('position.n.03'), Synset('regional.a.01'), Synset('international.a.01'), Synset('issue.n.01'), Synset('common.a.01'), Synset('interest.n.01'), Synset('ministry.n.01'), Synset('external.n.01'), Synset('personal_business.n.01'), Synset('statement.n.01'), Synset('japan.n.01'), Synset('reason.v.01'), Synset('particular.s.01'), Synset('partnership.n.01'), Synset('visit.n.01'), Synset('prime.n.01'), Synset('curate.n.01'), Synset('japan.n.01')] []
#  "The two sides will review all aspects of bilateral relations and exchange views on regional and international issues of common interest," a Ministry of External Affairs (MEA) statement said.India and Japan concluded a Special Strategic and Global Partnership during the visit of Prime Minister Narendra Modi to Japan in 2014.
# [] [Synset('side.n.01'), Synset('review.v.01'), Synset('aspect.n.01'), Synset('bilateral.s.01'), Synset('relations.n.01'), Synset('exchange.n.01'), Synset('position.n.03'), Synset('regional.a.01'), Synset('international.a.01'), Synset('issue.n.01'), Synset('common.a.01'), Synset('interest.n.01'), Synset('ministry.n.01'), Synset('external.n.01'), Synset('personal_business.n.01'), Synset('statement.n.01'), Synset('japan.n.01'), Synset('reason.v.01'), Synset('particular.s.01'), Synset('partnership.n.01'), Synset('visit.n.01'), Synset('prime.n.01'), Synset('curate.n.01'), Synset('japan.n.01')]
# Japanese Prime Minister Shinzo Abe had also visited India in September 2017.Bilateral relations have been strengthened in diverse sectors in recent years.
# [Synset('japanese.a.01'), Synset('prime.n.01'), Synset('curate.n.01'), Synset('have.v.01'), Synset('besides.r.02'), Synset('visit.v.01'), Synset('india.n.01'), Synset('september.n.01'), Synset('relations.n.01'), Synset('have.v.01'), Synset('be.v.01'), Synset('strengthen.v.01'), Synset('divers.s.01'), Synset('sector.n.01'), Synset('recent.s.01'), Synset('old_age.n.01')] []
#  Japanese Prime Minister Shinzo Abe had also visited India in September 2017.Bilateral relations have been strengthened in diverse sectors in recent years.
# [] [Synset('japanese.a.01'), Synset('prime.n.01'), Synset('curate.n.01'), Synset('have.v.01'), Synset('besides.r.02'), Synset('visit.v.01'), Synset('india.n.01'), Synset('september.n.01'), Synset('relations.n.01'), Synset('have.v.01'), Synset('be.v.01'), Synset('strengthen.v.01'), Synset('divers.s.01'), Synset('sector.n.01'), Synset('recent.s.01'), Synset('old_age.n.01')]
# India and Japan have a strong cooperation in the areas of nuclear energy, defence and science and technology.The Mumbai to Ahmedabad High Speed Rail project will be based on the Shinkansen super speed trains in Japan.Japan is today one of the largest investors in India, with a growing presence in infrastructure projects, manufacturing, financial markets and capacity-building, among others.According to official figures, Japanese FDI in India during 2016-17 was USD 4.7 billion, an increase of 80 per cent over the last year.In 2016-17, India-Japan trade reached USD 13.61 billion, showing a decrease of 6.21 per cent over 2015-16, when the total bilateral trade was USD 14.51 billion.India's export to Japan for 2016-17 was USD 3.86 billion, whereas India's import from the East Asian country for 2016-17 was USD 9.76 billion.
# [Synset('india.n.01'), Synset('japan.n.01'), Synset('have.v.01'), Synset('strong.a.01'), Synset('cooperation.n.01'), Synset('area.n.01'), Synset('nuclear.a.01'), Synset('energy.n.01'), Synset('defense_mechanism.n.01'), Synset('science.n.01'), Synset('mumbai.n.01'), Synset('high.n.01'), Synset('speed.n.01'), Synset('railing.n.01'), Synset('undertaking.n.01'), Synset('be.v.01'), Synset('establish.v.08'), Synset('superintendent.n.02'), Synset('speed.n.01'), Synset('train.n.01'), Synset('be.v.01'), Synset('today.n.01'), Synset('large.a.01'), Synset('investor.n.01'), Synset('india.n.01'), Synset('turn.v.07'), Synset('presence.n.01'), Synset('infrastructure.n.01'), Synset('undertaking.n.01'), Synset('fabrication.n.03'), Synset('fiscal.a.01'), Synset('market.n.01'), Synset('official.a.01'), Synset('figure.n.01'), Synset('japanese.a.01'), Synset('india.n.01'), Synset('be.v.01'), Synset('addition.n.03'), Synset('cent.n.01'), Synset('last.s.01'), Synset('trade.n.01'), Synset('reach.v.01'), Synset('show.v.01'), Synset('decrease.n.01'), Synset('cent.n.01'), Synset('entire.s.01'), Synset('bilateral.s.01'), Synset('trade.n.01'), Synset('be.v.01'), Synset('export.n.01'), Synset('japan.n.01'), Synset('be.v.01'), Synset('india.n.01'), Synset('import.n.01'), Synset('east.n.01'), Synset('asian.a.01'), Synset('state.n.04'), Synset('be.v.01')] []
#  India and Japan have a strong cooperation in the areas of nuclear energy, defence and science and technology.The Mumbai to Ahmedabad High Speed Rail project will be based on the Shinkansen super speed trains in Japan.Japan is today one of the largest investors in India, with a growing presence in infrastructure projects, manufacturing, financial markets and capacity-building, among others.According to official figures, Japanese FDI in India during 2016-17 was USD 4.7 billion, an increase of 80 per cent over the last year.In 2016-17, India-Japan trade reached USD 13.61 billion, showing a decrease of 6.21 per cent over 2015-16, when the total bilateral trade was USD 14.51 billion.India's export to Japan for 2016-17 was USD 3.86 billion, whereas India's import from the East Asian country for 2016-17 was USD 9.76 billion.
# [] [Synset('india.n.01'), Synset('japan.n.01'), Synset('have.v.01'), Synset('strong.a.01'), Synset('cooperation.n.01'), Synset('area.n.01'), Synset('nuclear.a.01'), Synset('energy.n.01'), Synset('defense_mechanism.n.01'), Synset('science.n.01'), Synset('mumbai.n.01'), Synset('high.n.01'), Synset('speed.n.01'), Synset('railing.n.01'), Synset('undertaking.n.01'), Synset('be.v.01'), Synset('establish.v.08'), Synset('superintendent.n.02'), Synset('speed.n.01'), Synset('train.n.01'), Synset('be.v.01'), Synset('today.n.01'), Synset('large.a.01'), Synset('investor.n.01'), Synset('india.n.01'), Synset('turn.v.07'), Synset('presence.n.01'), Synset('infrastructure.n.01'), Synset('undertaking.n.01'), Synset('fabrication.n.03'), Synset('fiscal.a.01'), Synset('market.n.01'), Synset('official.a.01'), Synset('figure.n.01'), Synset('japanese.a.01'), Synset('india.n.01'), Synset('be.v.01'), Synset('addition.n.03'), Synset('cent.n.01'), Synset('last.s.01'), Synset('trade.n.01'), Synset('reach.v.01'), Synset('show.v.01'), Synset('decrease.n.01'), Synset('cent.n.01'), Synset('entire.s.01'), Synset('bilateral.s.01'), Synset('trade.n.01'), Synset('be.v.01'), Synset('export.n.01'), Synset('japan.n.01'), Synset('be.v.01'), Synset('india.n.01'), Synset('import.n.01'), Synset('east.n.01'), Synset('asian.a.01'), Synset('state.n.04'), Synset('be.v.01')]
# Added to inputs.txt
# ----------------
# Article number 3
# https://thelogicalindian.com/environment/illegal-stone-quarries-in-bannerghatta/
# And on the other, another environmental problem has come to light about the illegal quarries in Bannerghatta National Park.
# [Synset('other.a.01'), Synset('environmental.a.01'), Synset('problem.n.01'), Synset('have.v.01'), Synset('come.v.01'), Synset('light.v.01'), Synset('illegal.a.01'), Synset('prey.n.01'), Synset('national.n.01'), Synset('park.n.01')] []
#  And on the other, another environmental problem has come to light about the illegal quarries in Bannerghatta National Park.
# [] [Synset('other.a.01'), Synset('environmental.a.01'), Synset('problem.n.01'), Synset('have.v.01'), Synset('come.v.01'), Synset('light.v.01'), Synset('illegal.a.01'), Synset('prey.n.01'), Synset('national.n.01'), Synset('park.n.01')]
# Almost 200 trucks transport granite from the outskirts of Bannerghatta National Park every day.
# [Synset('about.r.07'), Synset('truck.n.01'), Synset('transport.v.01'), Synset('granite.n.01'), Synset('outskirts.n.01'), Synset('national.n.01'), Synset('park.n.01'), Synset('day.n.01')] []
#  Almost 200 trucks transport granite from the outskirts of Bannerghatta National Park every day.
# [] [Synset('about.r.07'), Synset('truck.n.01'), Synset('transport.v.01'), Synset('granite.n.01'), Synset('outskirts.n.01'), Synset('national.n.01'), Synset('park.n.01'), Synset('day.n.01')]
# Many environmentalists and civic activists have launched an online campaign titled ‘Bannerghatta National Park in Grave Danger-Act Now!’, demanding the state government to act fast and save the forest.
# [Synset('many.a.01'), Synset('environmentalist.n.01'), Synset('civic.a.01'), Synset('militant.n.01'), Synset('have.v.01'), Synset('establish.v.01'), Synset('political_campaign.n.01'), Synset('entitle.v.02'), Synset('national.n.01'), Synset('park.n.01'), Synset('grave.n.01'), Synset('now.r.01'), Synset('demand.v.01'), Synset('state.n.01'), Synset('government.n.01'), Synset('act.v.01'), Synset('fast.r.01'), Synset('salvage.v.01'), Synset('forest.n.01')] []
#  Many environmentalists and civic activists have launched an online campaign titled ‘Bannerghatta National Park in Grave Danger-Act Now!’, demanding the state government to act fast and save the forest.
# [] [Synset('many.a.01'), Synset('environmentalist.n.01'), Synset('civic.a.01'), Synset('militant.n.01'), Synset('have.v.01'), Synset('establish.v.01'), Synset('political_campaign.n.01'), Synset('entitle.v.02'), Synset('national.n.01'), Synset('park.n.01'), Synset('grave.n.01'), Synset('now.r.01'), Synset('demand.v.01'), Synset('state.n.01'), Synset('government.n.01'), Synset('act.v.01'), Synset('fast.r.01'), Synset('salvage.v.01'), Synset('forest.n.01')]
# The notification issued categorises stone quarrying and crushing as prohibited activities.
# [Synset('presentment.n.01'), Synset('publish.v.02'), Synset('categorize.v.01'), Synset('rock.n.01'), Synset('quarrying.n.01'), Synset('suppression.n.03'), Synset('forbidden.s.01'), Synset('activity.n.01')] []
#  The notification issued categorises stone quarrying and crushing as prohibited activities.
# [] [Synset('presentment.n.01'), Synset('publish.v.02'), Synset('categorize.v.01'), Synset('rock.n.01'), Synset('quarrying.n.01'), Synset('suppression.n.03'), Synset('forbidden.s.01'), Synset('activity.n.01')]
# Local politicians who have vested interest in stone quarrying are trying their level best to dilute the notification by reducing the prohibited area.
# [Synset('local.a.01'), Synset('politician.n.01'), Synset('have.v.01'), Synset('invest.v.04'), Synset('interest.n.01'), Synset('rock.n.01'), Synset('quarrying.n.01'), Synset('be.v.01'), Synset('try.v.01'), Synset('degree.n.01'), Synset('best.a.01'), Synset('dilute.v.01'), Synset('presentment.n.01'), Synset('reduce.v.01'), Synset('forbidden.s.01'), Synset('area.n.01')] []
#  Local politicians who have vested interest in stone quarrying are trying their level best to dilute the notification by reducing the prohibited area.
# [] [Synset('local.a.01'), Synset('politician.n.01'), Synset('have.v.01'), Synset('invest.v.04'), Synset('interest.n.01'), Synset('rock.n.01'), Synset('quarrying.n.01'), Synset('be.v.01'), Synset('try.v.01'), Synset('degree.n.01'), Synset('best.a.01'), Synset('dilute.v.01'), Synset('presentment.n.01'), Synset('reduce.v.01'), Synset('forbidden.s.01'), Synset('area.n.01')]
# Added to inputs.txt
# ----------------
# Article number 4
# https://timesofindia.indiatimes.com/city/pune/beed-girl-throws-light-on-rampant-mass-copying-before-child-rights-commission/articleshow/63472161.cms
# PUNE: Preeta Sanap , a graduate from Shirur Kasar village in Beed district, on Monday claimed that mass copying was common in most colleges in the rural areas of the state.She alleged that teachers allowed students to copy and gave them permission to keep notebooks on desks during examinations.
# [Synset('alumnus.n.01'), Synset('village.n.01'), Synset('district.n.01'), Synset('monday.n.01'), Synset('claim.v.01'), Synset('mass.n.01'), Synset('copying.n.01'), Synset('be.v.01'), Synset('common.a.01'), Synset('most.a.01'), Synset('college.n.01'), Synset('rural.a.01'), Synset('area.n.01'), Synset('allege.v.01'), Synset('teacher.n.01'), Synset('let.v.01'), Synset('student.n.01'), Synset('copy.v.01'), Synset('give.v.01'), Synset('permission.n.01'), Synset('keep.v.01'), Synset('notebook.n.01'), Synset('desk.n.01'), Synset('examination.n.01')] []
#  PUNE: Preeta Sanap , a graduate from Shirur Kasar village in Beed district, on Monday claimed that mass copying was common in most colleges in the rural areas of the state.She alleged that teachers allowed students to copy and gave them permission to keep notebooks on desks during examinations.
# [] [Synset('alumnus.n.01'), Synset('village.n.01'), Synset('district.n.01'), Synset('monday.n.01'), Synset('claim.v.01'), Synset('mass.n.01'), Synset('copying.n.01'), Synset('be.v.01'), Synset('common.a.01'), Synset('most.a.01'), Synset('college.n.01'), Synset('rural.a.01'), Synset('area.n.01'), Synset('allege.v.01'), Synset('teacher.n.01'), Synset('let.v.01'), Synset('student.n.01'), Synset('copy.v.01'), Synset('give.v.01'), Synset('permission.n.01'), Synset('keep.v.01'), Synset('notebook.n.01'), Synset('desk.n.01'), Synset('examination.n.01')]
# Dearth of teachers in classes bugged her, too.Sanap made these shocking revelations during a public hearing conducted by the Maharashtra State Commission for Protection of Child Rights recently.The members of the commission stated that mass copying seemed to be common in rural areas.
# [Synset('dearth.n.01'), Synset('teacher.n.01'), Synset('class.n.01'), Synset('tease.v.01'), Synset('make.v.01'), Synset('shock.v.01'), Synset('disclosure.n.01'), Synset('public.a.01'), Synset('hearing.n.01'), Synset('conduct.v.01'), Synset('maharashtra.n.01'), Synset('state.n.01'), Synset('committee.n.01'), Synset('protection.n.01'), Synset('child.n.01'), Synset('right.n.01'), Synset('member.n.01'), Synset('committee.n.01'), Synset('state.v.01'), Synset('mass.n.01'), Synset('copying.n.01'), Synset('look.v.02'), Synset('be.v.01'), Synset('common.a.01'), Synset('rural.a.01'), Synset('area.n.01')] []
#  Dearth of teachers in classes bugged her, too.Sanap made these shocking revelations during a public hearing conducted by the Maharashtra State Commission for Protection of Child Rights recently.The members of the commission stated that mass copying seemed to be common in rural areas.
# [] [Synset('dearth.n.01'), Synset('teacher.n.01'), Synset('class.n.01'), Synset('tease.v.01'), Synset('make.v.01'), Synset('shock.v.01'), Synset('disclosure.n.01'), Synset('public.a.01'), Synset('hearing.n.01'), Synset('conduct.v.01'), Synset('maharashtra.n.01'), Synset('state.n.01'), Synset('committee.n.01'), Synset('protection.n.01'), Synset('child.n.01'), Synset('right.n.01'), Synset('member.n.01'), Synset('committee.n.01'), Synset('state.v.01'), Synset('mass.n.01'), Synset('copying.n.01'), Synset('look.v.02'), Synset('be.v.01'), Synset('common.a.01'), Synset('rural.a.01'), Synset('area.n.01')]
# We run some vocational courses at our NGO for girls willing to learn some skills and start an income.
# [Synset('run.v.01'), Synset('vocational.a.01'), Synset('course.n.01'), Synset('nongovernmental_organization.n.01'), Synset('girl.n.01'), Synset('willing.a.01'), Synset('learn.v.01'), Synset('skill.n.01'), Synset('get_down.v.07'), Synset('income.n.01')] []
#  We run some vocational courses at our NGO for girls willing to learn some skills and start an income.
# [] [Synset('run.v.01'), Synset('vocational.a.01'), Synset('course.n.01'), Synset('nongovernmental_organization.n.01'), Synset('girl.n.01'), Synset('willing.a.01'), Synset('learn.v.01'), Synset('skill.n.01'), Synset('get_down.v.07'), Synset('income.n.01')]
# These girls are in the age group of 11-18 but they simply cannot write.”Deshpande said teachers should be held responsible and penalized if their students failed to perform.
# [Synset('girl.n.01'), Synset('be.v.01'), Synset('age.n.01'), Synset('group.n.01'), Synset('merely.r.01'), Synset('not.r.01'), Synset('state.v.01'), Synset('teacher.n.01'), Synset('be.v.01'), Synset('keep.v.01'), Synset('responsible.a.01'), Synset('student.n.01'), Synset('fail.v.01'), Synset('perform.v.01')] []
#  These girls are in the age group of 11-18 but they simply cannot write.”Deshpande said teachers should be held responsible and penalized if their students failed to perform.
# [] [Synset('girl.n.01'), Synset('be.v.01'), Synset('age.n.01'), Synset('group.n.01'), Synset('merely.r.01'), Synset('not.r.01'), Synset('state.v.01'), Synset('teacher.n.01'), Synset('be.v.01'), Synset('keep.v.01'), Synset('responsible.a.01'), Synset('student.n.01'), Synset('fail.v.01'), Synset('perform.v.01')]
# “On the one side, the government wants to shut down schools, while on the other hand, schools are being ruined by teachers and management though the students have the desire to learn,” said Deshpande.
# [Synset('side.n.01'), Synset('government.n.01'), Synset('desire.v.01'), Synset('close.v.01'), Synset('down.r.01'), Synset('school.n.01'), Synset('other.a.01'), Synset('hand.n.01'), Synset('school.n.01'), Synset('be.v.01'), Synset('be.v.01'), Synset('destroy.v.02'), Synset('teacher.n.01'), Synset('management.n.01'), Synset('student.n.01'), Synset('have.v.01'), Synset('desire.n.01'), Synset('learn.v.01'), Synset('state.v.01')] []
#  “On the one side, the government wants to shut down schools, while on the other hand, schools are being ruined by teachers and management though the students have the desire to learn,” said Deshpande.
# [] [Synset('side.n.01'), Synset('government.n.01'), Synset('desire.v.01'), Synset('close.v.01'), Synset('down.r.01'), Synset('school.n.01'), Synset('other.a.01'), Synset('hand.n.01'), Synset('school.n.01'), Synset('be.v.01'), Synset('be.v.01'), Synset('destroy.v.02'), Synset('teacher.n.01'), Synset('management.n.01'), Synset('student.n.01'), Synset('have.v.01'), Synset('desire.n.01'), Synset('learn.v.01'), Synset('state.v.01')]
# Added to inputs.txt
# ----------------
# Article number 5
# http://odishasuntimes.com/mahaprayan-ambulance-failure-in-odisha-body-carried-on-rickshaw-baby-delivered-in-auto/
# Bhubaneswar: Even after launching of Mahaprayan scheme, 108 ambulance, it appears to have failed with a series of incidents reported from across Odisha.
# [Synset('even.r.01'), Synset('establish.v.01'), Synset('scheme.n.01'), Synset('ambulance.n.01'), Synset('look.v.02'), Synset('have.v.01'), Synset('fail.v.01'), Synset('series.n.01'), Synset('incident.n.01'), Synset('report.v.01')] []
#  Bhubaneswar: Even after launching of Mahaprayan scheme, 108 ambulance, it appears to have failed with a series of incidents reported from across Odisha.
# [] [Synset('even.r.01'), Synset('establish.v.01'), Synset('scheme.n.01'), Synset('ambulance.n.01'), Synset('look.v.02'), Synset('have.v.01'), Synset('fail.v.01'), Synset('series.n.01'), Synset('incident.n.01'), Synset('report.v.01')]
# Due to failure of ambulance service, a father had to carry his son’s body on his own rickshaw for funeral and an expectant mother delivered a baby in auto rickshaw.
# [Synset('due.a.01'), Synset('failure.n.01'), Synset('ambulance.n.01'), Synset('service.n.01'), Synset('father.n.01'), Synset('have.v.01'), Synset('transport.v.02'), Synset('son.n.01'), Synset('body.n.01'), Synset('own.s.01'), Synset('jinrikisha.n.01'), Synset('anticipant.s.01'), Synset('mother.n.01'), Synset('deliver.v.01'), Synset('baby.n.01'), Synset('car.n.01'), Synset('jinrikisha.n.01')] []
#  Due to failure of ambulance service, a father had to carry his son’s body on his own rickshaw for funeral and an expectant mother delivered a baby in auto rickshaw.
# [] [Synset('due.a.01'), Synset('failure.n.01'), Synset('ambulance.n.01'), Synset('service.n.01'), Synset('father.n.01'), Synset('have.v.01'), Synset('transport.v.02'), Synset('son.n.01'), Synset('body.n.01'), Synset('own.s.01'), Synset('jinrikisha.n.01'), Synset('anticipant.s.01'), Synset('mother.n.01'), Synset('deliver.v.01'), Synset('baby.n.01'), Synset('car.n.01'), Synset('jinrikisha.n.01')]
# As the ambulance was not available in the hospital, father Nirod had called for 108 ambulance service to carry his son’s body.
# [Synset('ambulance.n.01'), Synset('be.v.01'), Synset('not.r.01'), Synset('available.a.01'), Synset('hospital.n.01'), Synset('father.n.01'), Synset('have.v.01'), Synset('name.v.01'), Synset('ambulance.n.01'), Synset('service.n.01'), Synset('transport.v.02'), Synset('son.n.01'), Synset('second.n.01'), Synset('body.n.01')] []
#  As the ambulance was not available in the hospital, father Nirod had called for 108 ambulance service to carry his son’s body.
# [] [Synset('ambulance.n.01'), Synset('be.v.01'), Synset('not.r.01'), Synset('available.a.01'), Synset('hospital.n.01'), Synset('father.n.01'), Synset('have.v.01'), Synset('name.v.01'), Synset('ambulance.n.01'), Synset('service.n.01'), Synset('transport.v.02'), Synset('son.n.01'), Synset('second.n.01'), Synset('body.n.01')]
# Her family had called for 108 ambulance service to take the patient.
# [Synset('family.n.01'), Synset('have.v.01'), Synset('name.v.01'), Synset('ambulance.n.01'), Synset('service.n.01'), Synset('take.v.01'), Synset('patient.n.01')] []
#  Her family had called for 108 ambulance service to take the patient.
# [] [Synset('family.n.01'), Synset('have.v.01'), Synset('name.v.01'), Synset('ambulance.n.01'), Synset('service.n.01'), Synset('take.v.01'), Synset('patient.n.01')]
# She delivered a baby boy in an auto rickshaw midway while being taken to Balakati community health centre.
# [Synset('deliver.v.01'), Synset('baby.n.01'), Synset('male_child.n.01'), Synset('car.n.01'), Synset('jinrikisha.n.01'), Synset('midway.n.01'), Synset('be.v.01'), Synset('take.v.01'), Synset('community.n.01'), Synset('health.n.01'), Synset('centre.n.01')] []
#  She delivered a baby boy in an auto rickshaw midway while being taken to Balakati community health centre.
# [] [Synset('deliver.v.01'), Synset('baby.n.01'), Synset('male_child.n.01'), Synset('car.n.01'), Synset('jinrikisha.n.01'), Synset('midway.n.01'), Synset('be.v.01'), Synset('take.v.01'), Synset('community.n.01'), Synset('health.n.01'), Synset('centre.n.01')]
# Added to inputs.txt
# ----------------
# Article number 6
# https://economictimes.indiatimes.com/news/politics-and-nation/congress-will-disappear-from-karnataka-like-other-states-prakash-javadekar/articleshow/63487965.cms
# NEW DELHI: Union minister Prakash Javadekar , the BJP's in-charge for Karnataka polls, today claimed the Congress will "disappear" from the state like it has from other parts of the country and accused the Siddaramaiah government of being "anti-farmer and anti-poor".On a day the Election Commission announced May 12 as the polling date in the state, Javadekar claimed that the people there are eager to throw out the Congress government due to its "divide and rule policy".
# [Synset('new.a.01'), Synset('delhi.n.01'), Synset('union.n.01'), Synset('curate.n.01'), Synset('karnataka.n.01'), Synset('polls.n.01'), Synset('today.n.01'), Synset('claim.v.01'), Synset('congress.n.01'), Synset('disappear.v.01'), Synset('state.n.01'), Synset('have.v.01'), Synset('other.a.01'), Synset('parts.n.01'), Synset('state.n.04'), Synset('accuse.v.01'), Synset('government.n.01'), Synset('be.v.01'), Synset('day.n.01'), Synset('election.n.01'), Synset('committee.n.01'), Synset('announce.v.01'), Synset('may.n.01'), Synset('date.n.01'), Synset('state.n.01'), Synset('claim.v.01'), Synset('people.n.01'), Synset('be.v.01'), Synset('eager.a.01'), Synset('throw.v.01'), Synset('out.r.01'), Synset('congress.n.01'), Synset('government.n.01'), Synset('due.a.01'), Synset('divide.n.01'), Synset('rule.n.01'), Synset('policy.n.01')] []
#  NEW DELHI: Union minister Prakash Javadekar , the BJP's in-charge for Karnataka polls, today claimed the Congress will "disappear" from the state like it has from other parts of the country and accused the Siddaramaiah government of being "anti-farmer and anti-poor".On a day the Election Commission announced May 12 as the polling date in the state, Javadekar claimed that the people there are eager to throw out the Congress government due to its "divide and rule policy".
# [] [Synset('new.a.01'), Synset('delhi.n.01'), Synset('union.n.01'), Synset('curate.n.01'), Synset('karnataka.n.01'), Synset('polls.n.01'), Synset('today.n.01'), Synset('claim.v.01'), Synset('congress.n.01'), Synset('disappear.v.01'), Synset('state.n.01'), Synset('have.v.01'), Synset('other.a.01'), Synset('parts.n.01'), Synset('state.n.04'), Synset('accuse.v.01'), Synset('government.n.01'), Synset('be.v.01'), Synset('day.n.01'), Synset('election.n.01'), Synset('committee.n.01'), Synset('announce.v.01'), Synset('may.n.01'), Synset('date.n.01'), Synset('state.n.01'), Synset('claim.v.01'), Synset('people.n.01'), Synset('be.v.01'), Synset('eager.a.01'), Synset('throw.v.01'), Synset('out.r.01'), Synset('congress.n.01'), Synset('government.n.01'), Synset('due.a.01'), Synset('divide.n.01'), Synset('rule.n.01'), Synset('policy.n.01')]
# "The BJP is confident of a victory.
# [Synset('be.v.01'), Synset('confident.a.01'), Synset('victory.n.01')] []
#  "The BJP is confident of a victory.
# [] [Synset('be.v.01'), Synset('confident.a.01'), Synset('victory.n.01')]
# Their game is divide and rule.
# [Synset('game.n.01'), Synset('be.v.01'), Synset('rule.n.01')] []
#  Their game is divide and rule.
# [] [Synset('game.n.01'), Synset('be.v.01'), Synset('rule.n.01')]
# They are anti-poor and anti-farmers.
# [Synset('be.v.01')] []
#  They are anti-poor and anti-farmers.
# [] [Synset('be.v.01')]
# People don't appreciate such policies.
# [Synset('people.n.01'), Synset('make.v.01'), Synset('appreciate.v.01'), Synset('such.s.01'), Synset('policy.n.01')] []
#  People don't appreciate such policies.
# [] [Synset('people.n.01'), Synset('make.v.01'), Synset('appreciate.v.01'), Synset('such.s.01'), Synset('policy.n.01')]
# Added to inputs.txt
# ----------------
# Article number 7
# https://timesofindia.indiatimes.com/india/congress-will-disappear-from-karnataka-like-other-states-prakash-javadekar/articleshow/63487837.cms
# NEW DELHI: Union minister Prakash Javadekar , the BJP 's in-charge for Karnataka polls, on Tuesday claimed the Congress will "disappear" from the state like it has from other parts of the country and accused the Siddaramaiah government of being "anti-farmer and anti-poor".On a day the Election Commission announced May 12 as the polling date in the state, Javadekar claimed that the people there are eager to throw out the Congress government due to its "divide and rule policy".
# [Synset('new.a.01'), Synset('delhi.n.01'), Synset('union.n.01'), Synset('curate.n.01'), Synset('karnataka.n.01'), Synset('polls.n.01'), Synset('tuesday.n.01'), Synset('claim.v.01'), Synset('congress.n.01'), Synset('disappear.v.01'), Synset('state.n.01'), Synset('have.v.01'), Synset('other.a.01'), Synset('parts.n.01'), Synset('state.n.04'), Synset('accuse.v.01'), Synset('government.n.01'), Synset('be.v.01'), Synset('day.n.01'), Synset('election.n.01'), Synset('committee.n.01'), Synset('announce.v.01'), Synset('may.n.01'), Synset('date.n.01'), Synset('state.n.01'), Synset('claim.v.01'), Synset('people.n.01'), Synset('be.v.01'), Synset('eager.a.01'), Synset('throw.v.01'), Synset('out.r.01'), Synset('congress.n.01'), Synset('government.n.01'), Synset('due.a.01'), Synset('divide.n.01'), Synset('rule.n.01'), Synset('policy.n.01')] []
#  NEW DELHI: Union minister Prakash Javadekar , the BJP 's in-charge for Karnataka polls, on Tuesday claimed the Congress will "disappear" from the state like it has from other parts of the country and accused the Siddaramaiah government of being "anti-farmer and anti-poor".On a day the Election Commission announced May 12 as the polling date in the state, Javadekar claimed that the people there are eager to throw out the Congress government due to its "divide and rule policy".
# [] [Synset('new.a.01'), Synset('delhi.n.01'), Synset('union.n.01'), Synset('curate.n.01'), Synset('karnataka.n.01'), Synset('polls.n.01'), Synset('tuesday.n.01'), Synset('claim.v.01'), Synset('congress.n.01'), Synset('disappear.v.01'), Synset('state.n.01'), Synset('have.v.01'), Synset('other.a.01'), Synset('parts.n.01'), Synset('state.n.04'), Synset('accuse.v.01'), Synset('government.n.01'), Synset('be.v.01'), Synset('day.n.01'), Synset('election.n.01'), Synset('committee.n.01'), Synset('announce.v.01'), Synset('may.n.01'), Synset('date.n.01'), Synset('state.n.01'), Synset('claim.v.01'), Synset('people.n.01'), Synset('be.v.01'), Synset('eager.a.01'), Synset('throw.v.01'), Synset('out.r.01'), Synset('congress.n.01'), Synset('government.n.01'), Synset('due.a.01'), Synset('divide.n.01'), Synset('rule.n.01'), Synset('policy.n.01')]
# "The BJP is confident of a victory.
# [Synset('be.v.01'), Synset('confident.a.01'), Synset('victory.n.01')] []
#  "The BJP is confident of a victory.
# [] [Synset('be.v.01'), Synset('confident.a.01'), Synset('victory.n.01')]
# Their game is divide and rule.
# [Synset('game.n.01'), Synset('be.v.01'), Synset('rule.n.01')] []
#  Their game is divide and rule.
# [] [Synset('game.n.01'), Synset('be.v.01'), Synset('rule.n.01')]
# They are anti-poor and anti-farmers.
# [Synset('be.v.01')] []
#  They are anti-poor and anti-farmers.
# [] [Synset('be.v.01')]
# People don't appreciate such policies.
# [Synset('people.n.01'), Synset('make.v.01'), Synset('appreciate.v.01'), Synset('such.s.01'), Synset('policy.n.01')] []
#  People don't appreciate such policies.
# [] [Synset('people.n.01'), Synset('make.v.01'), Synset('appreciate.v.01'), Synset('such.s.01'), Synset('policy.n.01')]
# Added to inputs.txt
# ----------------
# Article number 8
# https://www.japantimes.co.jp/news/2018/03/27/asia-pacific/north-korean-leaders-train-unlike/#.WrpSnXVuY8o
# When North Korea’s leaders need to travel, they’ve got a train that’s unlike any other.
# [Synset('north.n.01'), Synset('korea.n.01'), Synset('second.n.01'), Synset('leadership.n.02'), Synset('necessitate.v.01'), Synset('travel.v.01'), Synset('get.v.01'), Synset('train.n.01'), Synset('second.n.01'), Synset('other.a.01')] []
#  When North Korea’s leaders need to travel, they’ve got a train that’s unlike any other.
# [] [Synset('north.n.01'), Synset('korea.n.01'), Synset('second.n.01'), Synset('leadership.n.02'), Synset('necessitate.v.01'), Synset('travel.v.01'), Synset('get.v.01'), Synset('train.n.01'), Synset('second.n.01'), Synset('other.a.01')]
# Here’s a look at what’s known about the North Korean ruling family’s personal version of the Orient Express.
# [Synset('here.r.01'), Synset('expression.n.01'), Synset('know.v.01'), Synset('north.a.01'), Synset('korean.a.01'), Synset('opinion.n.05'), Synset('family.n.01'), Synset('personal.a.01'), Synset('version.n.01'), Synset('east.n.02'), Synset('express.n.01')] []
#  Here’s a look at what’s known about the North Korean ruling family’s personal version of the Orient Express.
# [] [Synset('here.r.01'), Synset('expression.n.01'), Synset('know.v.01'), Synset('north.a.01'), Synset('korean.a.01'), Synset('opinion.n.05'), Synset('family.n.01'), Synset('personal.a.01'), Synset('version.n.01'), Synset('east.n.02'), Synset('express.n.01')]
# A version of the train open to the North Korean public is more businesslike.
# [Synset('version.n.01'), Synset('train.n.01'), Synset('open.a.01'), Synset('north.a.01'), Synset('korean.a.01'), Synset('populace.n.01'), Synset('be.v.01'), Synset('more.r.01'), Synset('businesslike.s.01')] []
#  A version of the train open to the North Korean public is more businesslike.
# [] [Synset('version.n.01'), Synset('train.n.01'), Synset('open.a.01'), Synset('north.a.01'), Synset('korean.a.01'), Synset('populace.n.01'), Synset('be.v.01'), Synset('more.r.01'), Synset('businesslike.s.01')]
# Advanced communications and flat screen TVs have been installed so the North Korean leader can give orders and receive news and briefings.
# [Synset('communications.n.01'), Synset('flat.s.01'), Synset('screen.n.01'), Synset('television.n.01'), Synset('have.v.01'), Synset('be.v.01'), Synset('install.v.01'), Synset('so.r.01'), Synset('north.a.01'), Synset('korean.a.01'), Synset('leader.n.01'), Synset('give.v.01'), Synset('order.n.01'), Synset('news.n.01'), Synset('briefing.n.01')] []
#  Advanced communications and flat screen TVs have been installed so the North Korean leader can give orders and receive news and briefings.
# [] [Synset('communications.n.01'), Synset('flat.s.01'), Synset('screen.n.01'), Synset('television.n.01'), Synset('have.v.01'), Synset('be.v.01'), Synset('install.v.01'), Synset('so.r.01'), Synset('north.a.01'), Synset('korean.a.01'), Synset('leader.n.01'), Synset('give.v.01'), Synset('order.n.01'), Synset('news.n.01'), Synset('briefing.n.01')]
# Experts still couch their estimates of how many times North Korean leaders have traveled abroad because some trips may still remain secret.
# [Synset('expert.n.01'), Synset('still.r.01'), Synset('frame.v.04'), Synset('estimate.n.01'), Synset('many.a.01'), Synset('times.n.01'), Synset('north.a.01'), Synset('korean.a.01'), Synset('leadership.n.02'), Synset('have.v.01'), Synset('travel.v.01'), Synset('abroad.r.01'), Synset('trip.n.01'), Synset('still.r.01'), Synset('stay.v.01'), Synset('secret.s.01')] []
#  Experts still couch their estimates of how many times North Korean leaders have traveled abroad because some trips may still remain secret.
# [] [Synset('expert.n.01'), Synset('still.r.01'), Synset('frame.v.04'), Synset('estimate.n.01'), Synset('many.a.01'), Synset('times.n.01'), Synset('north.a.01'), Synset('korean.a.01'), Synset('leadership.n.02'), Synset('have.v.01'), Synset('travel.v.01'), Synset('abroad.r.01'), Synset('trip.n.01'), Synset('still.r.01'), Synset('stay.v.01'), Synset('secret.s.01')]
# Added to inputs.txt
# ----------------
# Article number 9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-51ae9acccbbf> in <module>()
#       4     print ('Article number %d' % (i+1))
#       5     article = newspaper.Article(url=url, language='en')
# ----> 6     article.download()
#       7     article.parse()
#       8     article.nlp()
#
# /usr/local/lib/python3.5/dist-packages/newspaper/article.py in download(self, input_html, title, recursion_counter)
#     162         if input_html is None:
#     163             try:
# --> 164                 html = network.get_html_2XX_only(self.url, self.config)
#     165             except requests.exceptions.RequestException as e:
#     166                 self.download_state = ArticleDownloadState.FAILED_RESPONSE
#
# /usr/local/lib/python3.5/dist-packages/newspaper/network.py in get_html_2XX_only(url, config, response)
#      62     try:
#      63         response = requests.get(
# ---> 64             url=url, **get_request_kwargs(timeout, useragent, proxies, headers))
#      65     except requests.exceptions.RequestException as e:
#      66         log.debug('get_html_2XX_only() error. %s on URL: %s' % (e, url))
#
# /usr/local/lib/python3.5/dist-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /usr/local/lib/python3.5/dist-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /usr/local/lib/python3.5/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /usr/local/lib/python3.5/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.5/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# /usr/local/lib/python3.5/dist-packages/urllib3/connection.py in connect(self)
#     324             ca_cert_dir=self.ca_cert_dir,
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#     328         if self.assert_fingerprint:
#
# /usr/local/lib/python3.5/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     327         context.load_cert_chain(certfile, keyfile)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#     331     warnings.warn(
#
# /usr/lib/python3.5/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     375                          suppress_ragged_eofs=suppress_ragged_eofs,
#     376                          server_hostname=server_hostname,
# --> 377                          _context=self)
#     378
#     379     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# /usr/lib/python3.5/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context)
#     750                         # non-blocking
#     751                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 752                     self.do_handshake()
#     753
#     754             except (OSError, ValueError):
#
# /usr/lib/python3.5/ssl.py in do_handshake(self, block)
#     986             if timeout == 0.0 and block:
#     987                 self.settimeout(None)
# --> 988             self._sslobj.do_handshake()
#     989         finally:
#     990             self.settimeout(timeout)
#
# /usr/lib/python3.5/ssl.py in do_handshake(self)
#     631     def do_handshake(self):
#     632         """Start the SSL/TLS handshake."""
# --> 633         self._sslobj.do_handshake()
#     634         if self.context.check_hostname:
#     635             if not self.server_hostname:
#
# KeyboardInterrupt:
