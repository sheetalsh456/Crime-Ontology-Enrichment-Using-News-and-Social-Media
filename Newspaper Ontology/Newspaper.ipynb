# %%
import newspaper

# %%
file = open('urls', 'r')
data = file.readlines()

urls = []

for url in data:
    url = url.rstrip('\n')
    urls.append(url)
    
urls
# Out:
# ['https://timesofindia.indiatimes.com/city/mumbai/6-year-old-abducted-girl-found-dead-in-railway-toilet-in-navsari/articleshow/63462708.cms',
#  'https://economictimes.indiatimes.com/news/politics-and-nation/sushma-swaraj-to-visit-japan-for-strategic-dialogue/articleshow/63488634.cms',
#  'https://thelogicalindian.com/environment/illegal-stone-quarries-in-bannerghatta/',
#  'https://timesofindia.indiatimes.com/city/pune/beed-girl-throws-light-on-rampant-mass-copying-before-child-rights-commission/articleshow/63472161.cms',
#  'http://odishasuntimes.com/mahaprayan-ambulance-failure-in-odisha-body-carried-on-rickshaw-baby-delivered-in-auto/',
#  'https://economictimes.indiatimes.com/news/politics-and-nation/congress-will-disappear-from-karnataka-like-other-states-prakash-javadekar/articleshow/63487965.cms',
#  'https://timesofindia.indiatimes.com/india/congress-will-disappear-from-karnataka-like-other-states-prakash-javadekar/articleshow/63487837.cms',
#  'https://www.japantimes.co.jp/news/2018/03/27/asia-pacific/north-korean-leaders-train-unlike/#.WrpSnXVuY8o',
#  'https://www.nytimes.com/aponline/2018/03/27/world/asia/ap-as-nkorea-the-mystery-train.html',
#  'https://timesofindia.indiatimes.com/india/amit-shah-accuses-siddaramaiah-govt-of-dividing-hindus/articleshow/63482038.cms',
#  'https://www.thehindubusinessline.com/news/national/amit-shah-accuses-siddaramaiah-govt-of-dividing-hindus/article23364780.ece',
#  'https://timesofindia.indiatimes.com/city/bengaluru/karnataka-polls-not-averse-to-seers-and-pontiffs-contesting-on-our-party-ticket-says-amit-shah/articleshow/63480352.cms',
#  'http://theworldvibe.com/63480378-cms/',
#  'http://brighterkashmir.com/man-loses-wife-and-2-kids-in-gambling-gets-divorce/',
#  'https://timesofindia.indiatimes.com/city/kanpur/Man-loses-wife-as-stake-in-IPL-gambling/articleshow/52480224.cms',
#  'https://timesofindia.indiatimes.com/india/heated-exchanges-between-aiadmk-congress-mps-after-lok-sabha-adjourns/articleshow/63480945.cms',
#  'https://www.indiatoday.in/pti-feed/story/heated-exchanges-between-aiadmk-cong-mps-after-ls-adjourns-1198771-2018-03-27',
#  'https://timesofindia.indiatimes.com/india/jk-undo-negative-perception-about-kashmir-says-tourism-minister-tassaduq-mufti/articleshow/63485013.cms',
#  'https://dailyworld.in/undo-negative-perception-about-kashmir-says-tourism-minister/',
#  'https://timesofindia.indiatimes.com/india/up-assembly-passes-stringent-crime-control-bill-amid-opposition-walkout/articleshow/63483701.cms',
#  'https://www.theweek.in/news/india/2018/03/27/uttar-pradesh-assembly-passes-stringent-crime-control-bill-amid-opposition-walkout.html',
#  'https://timesofindia.indiatimes.com/india/cbdt-extends-pan-aadhaar-linking-deadline-to-june-30/articleshow/63491050.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop',
#  'https://timesofindia.indiatimes.com/india/sushma-swaraj-to-visit-japan-for-strategic-dialogue/articleshow/63486098.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop',
#  'https://timesofindia.indiatimes.com/india/congress-will-disappear-from-karnataka-like-other-states-prakash-javadekar/articleshow/63487837.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop',
#  'https://blogs.timesofindia.indiatimes.com/sanjeev-singh-blog/did-samajwadi-party-really-want-bsp-to-win-up-rajya-sabha-polls/',
#  'https://timesofindia.indiatimes.com/india/delhi-court-orders-attachment-of-vijay-mallyas-properties-in-pmla-case/articleshow/63486193.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop',
#  'http://indianexpress.com/article/india/crime/assam-crowds-throng-centres-to-check-draft-nrc-many-nellie-muslims-not-on-list-5008067 ',
#  'http://indianexpress.com/article/india/crime/railway-push-to-heritage-conservation-steam-engines-to-return-to-mountains-4966587 ',
#  'http://indianexpress.com/article/india/crime/pak-border-squeeze-chokes-indian-traders',
#  'http://indianexpress.com/article/india/crime/another-accused-in-pehlu-khan-lynching-case-gets-bail-4789888 ']

# %%
from nltk import *
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn

# %%
def penn_to_wn(tag):
    """ Convert between a Penn Treebank tag to a simplified Wordnet tag """
    if tag.startswith('N'):
        return 'n'
 
    if tag.startswith('V'):
        return 'v'
 
    if tag.startswith('J'):
        return 'a'
 
    if tag.startswith('R'):
        return 'r'
 
    return None
 
def tagged_to_synset(word, tag):
    wn_tag = penn_to_wn(tag)
    if wn_tag is None:
        return None
    try:
        return wn.synsets(word, wn_tag)[0]
    except:
        return None

# %%
def sentence_similarity(sentence1, sentence2):
    """ compute the sentence similarity using Wordnet """
#     print(sentence1, sentence2)
    # Tokenize and tag
    sentence1 = pos_tag(word_tokenize(sentence1))
    sentence2 = pos_tag(word_tokenize(sentence2))
 
    # Get the synsets for the tagged words
    synsets1 = [tagged_to_synset(*tagged_word) for tagged_word in sentence1]
    synsets2 = [tagged_to_synset(*tagged_word) for tagged_word in sentence2]
 
    # Filter out the Nones
    synsets1 = [ss for ss in synsets1 if ss]
    synsets2 = [ss for ss in synsets2 if ss]

#     print(synsets1, synsets2)
    score, count = 0.0, 0
 
    # For each word in the first sentence
    for synset in synsets1:
        # Get the similarity value of the most similar word in the other sentence
        scores = [synset.path_similarity(ss) for ss in synsets2]
        scores.append(0)
        best_score = max([score for score in scores if score is not None])
 
        # Check that the similarity could have been computed
        if best_score is not None:
            score += best_score
            count += 1
 
    # Average the values
    if count != 0:
        score /= count
    return score

def symmetric_sentence_similarity(sentence1, sentence2):
    """ compute the symmetric sentence similarity using Wordnet """
    return (sentence_similarity(sentence1, sentence2) + sentence_similarity(sentence2, sentence1)) / 2

# %%
def get_continuous_chunks(text):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []
    for i in chunked:
            if type(i) == Tree:
                current_chunk.append(i.label()[:3] + "-")
                current_chunk.append(" ".join([token for token, pos in i.leaves()]))
            elif current_chunk:
                named_entity = " ".join(current_chunk)
                if named_entity not in continuous_chunk:
                    continuous_chunk.append(named_entity)
                    current_chunk = []
            else:
                continue
    return continuous_chunk

# %%
def get_relation_tuples(sentences, image, image_caption):
    relation_tuples = []
    for sentence in sentences:
        similarity_score = symmetric_sentence_similarity(sentence, image_caption)
        rel_tuple_single = []
        rel_tuple_single = get_continuous_chunks(sentence)
        
        if len(rel_tuple_single):
            tokens = word_tokenize(sentence)
            tagged = pos_tag(tokens)

        entities = chunk.ne_chunk(tagged)
        for entity in entities:
            if len(entity)>1 and (entity[1] == 'VB' or entity[1] == 'VBD' or entity[1] == 'VBN' or entity[1] == 'VM'):
                if entity[0] not in stopwords.words('english'):
                    rel_tuple_single.append('REL-'+entity[0])
        rel_tuple_single.append('IMG-'+image)
        rel_tuple_single.append('RM-'+str(similarity_score))

        if len(rel_tuple_single):
            relation_tuples.append(rel_tuple_single)

    with open("input.txt", "a") as myfile:
        myfile.write(str(relation_tuples)+'\n')

# %%
from requests import get
from bs4 import BeautifulSoup

def get_image_caption(url):
    response = get(url)
    caption = ""
    html_soup = BeautifulSoup(response.text, 'html.parser')
    print(url)
    if url.find('indianexpress') is not -1:
        image_containers = html_soup.find_all('span', class_ = 'custom-caption')
        if len(image_containers):
            caption = image_containers[0].text
    elif url.find('deccanchronicle') is not -1:
        image_containers = html_soup.find_all('div', class_ = 'storyimg-caption')
        if len(image_containers):
            caption = image_containers[0].text
    return caption

# %%
articles = []

for i, url in enumerate(urls):
    print ('Article number %d' % (i+1))
    article = newspaper.Article(url=url, language='en')
    article.download()
    article.parse()
    article.nlp()
    try:
        get_relation_tuples(sent_tokenize(article.summary), article.top_image, get_image_caption(url))
        print('Added to inputs.txt')
    except:
        print ('Invalid Article')
    print ('----------------')
# Out:
# Article number 1
# https://timesofindia.indiatimes.com/city/mumbai/6-year-old-abducted-girl-found-dead-in-railway-toilet-in-navsari/articleshow/63462708.cms
# Added to inputs.txt
# ----------------
# Article number 2
# https://economictimes.indiatimes.com/news/politics-and-nation/sushma-swaraj-to-visit-japan-for-strategic-dialogue/articleshow/63488634.cms
# Added to inputs.txt
# ----------------
# Article number 3
# https://thelogicalindian.com/environment/illegal-stone-quarries-in-bannerghatta/
# Added to inputs.txt
# ----------------
# Article number 4
# https://timesofindia.indiatimes.com/city/pune/beed-girl-throws-light-on-rampant-mass-copying-before-child-rights-commission/articleshow/63472161.cms
# Added to inputs.txt
# ----------------
# Article number 5
# http://odishasuntimes.com/mahaprayan-ambulance-failure-in-odisha-body-carried-on-rickshaw-baby-delivered-in-auto/
# Added to inputs.txt
# ----------------
# Article number 6
# https://economictimes.indiatimes.com/news/politics-and-nation/congress-will-disappear-from-karnataka-like-other-states-prakash-javadekar/articleshow/63487965.cms
# Added to inputs.txt
# ----------------
# Article number 7
# https://timesofindia.indiatimes.com/india/congress-will-disappear-from-karnataka-like-other-states-prakash-javadekar/articleshow/63487837.cms
# Added to inputs.txt
# ----------------
# Article number 8
# https://www.japantimes.co.jp/news/2018/03/27/asia-pacific/north-korean-leaders-train-unlike/#.WrpSnXVuY8o
# Added to inputs.txt
# ----------------
# Article number 9
# https://www.nytimes.com/aponline/2018/03/27/world/asia/ap-as-nkorea-the-mystery-train.html
# Added to inputs.txt
# ----------------
# Article number 10
# https://timesofindia.indiatimes.com/india/amit-shah-accuses-siddaramaiah-govt-of-dividing-hindus/articleshow/63482038.cms
# Added to inputs.txt
# ----------------
# Article number 11
# Invalid Article
# ----------------
# Article number 12
# https://timesofindia.indiatimes.com/city/bengaluru/karnataka-polls-not-averse-to-seers-and-pontiffs-contesting-on-our-party-ticket-says-amit-shah/articleshow/63480352.cms
# Added to inputs.txt
# ----------------
# Article number 13
# http://theworldvibe.com/63480378-cms/
# Added to inputs.txt
# ----------------
# Article number 14
# http://brighterkashmir.com/man-loses-wife-and-2-kids-in-gambling-gets-divorce/
# Added to inputs.txt
# ----------------
# Article number 15
# https://timesofindia.indiatimes.com/city/kanpur/Man-loses-wife-as-stake-in-IPL-gambling/articleshow/52480224.cms
# Added to inputs.txt
# ----------------
# Article number 16
# https://timesofindia.indiatimes.com/india/heated-exchanges-between-aiadmk-congress-mps-after-lok-sabha-adjourns/articleshow/63480945.cms
# Added to inputs.txt
# ----------------
# Article number 17
# https://www.indiatoday.in/pti-feed/story/heated-exchanges-between-aiadmk-cong-mps-after-ls-adjourns-1198771-2018-03-27
# Added to inputs.txt
# ----------------
# Article number 18
# https://timesofindia.indiatimes.com/india/jk-undo-negative-perception-about-kashmir-says-tourism-minister-tassaduq-mufti/articleshow/63485013.cms
# Added to inputs.txt
# ----------------
# Article number 19
# https://dailyworld.in/undo-negative-perception-about-kashmir-says-tourism-minister/
# Added to inputs.txt
# ----------------
# Article number 20
# https://timesofindia.indiatimes.com/india/up-assembly-passes-stringent-crime-control-bill-amid-opposition-walkout/articleshow/63483701.cms
# Invalid Article
# ----------------
# Article number 21
# https://www.theweek.in/news/india/2018/03/27/uttar-pradesh-assembly-passes-stringent-crime-control-bill-amid-opposition-walkout.html
# Added to inputs.txt
# ----------------
# Article number 22
# https://timesofindia.indiatimes.com/india/cbdt-extends-pan-aadhaar-linking-deadline-to-june-30/articleshow/63491050.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop
# Added to inputs.txt
# ----------------
# Article number 23
# https://timesofindia.indiatimes.com/india/sushma-swaraj-to-visit-japan-for-strategic-dialogue/articleshow/63486098.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop
# Added to inputs.txt
# ----------------
# Article number 24
# https://timesofindia.indiatimes.com/india/congress-will-disappear-from-karnataka-like-other-states-prakash-javadekar/articleshow/63487837.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop
# Added to inputs.txt
# ----------------
# Article number 25
# https://blogs.timesofindia.indiatimes.com/sanjeev-singh-blog/did-samajwadi-party-really-want-bsp-to-win-up-rajya-sabha-polls/
# Added to inputs.txt
# ----------------
# Article number 26
# https://timesofindia.indiatimes.com/india/delhi-court-orders-attachment-of-vijay-mallyas-properties-in-pmla-case/articleshow/63486193.cms?utm_source=twitter.com&utm_medium=social&utm_campaign=TOIDesktop
# Added to inputs.txt
# ----------------
# Article number 27
# http://indianexpress.com/article/india/crime/assam-crowds-throng-centres-to-check-draft-nrc-many-nellie-muslims-not-on-list-5008067
# Added to inputs.txt
# ----------------
# Article number 28
# http://indianexpress.com/article/india/crime/railway-push-to-heritage-conservation-steam-engines-to-return-to-mountains-4966587
# Added to inputs.txt
# ----------------
# Article number 29
# http://indianexpress.com/article/india/crime/pak-border-squeeze-chokes-indian-traders
# Added to inputs.txt
# ----------------
# Article number 30
# http://indianexpress.com/article/india/crime/another-accused-in-pehlu-khan-lynching-case-gets-bail-4789888
# Added to inputs.txt
# ----------------
